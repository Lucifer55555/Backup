# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.arange(0,11,2.5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
x=np.linspace(0,10,100)

# %% [markdown]
# plt.plot(x, np.sin(x))

# %% [markdown]
# __%matplotlib inline -- it generates a static plot,this is default__
# __%matplotlib notebook -- makes the plot interactive__

# %%
# %matplotlib notebook
plt.plot(x, np.sin(x),"-")
plt.plot(x, np.cos(x),".")
plt.plot(x, np.tan(x),"--")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999682108573">

# %% [markdown]
# ### SUBPLOT

# %%
plt.style.use('classic')
plt.figure(figsize=(5,7))

plt.subplot(2,1,1)
plt.plot(x, np.sin(x))

plt.subplot(2,1,2)
plt.plot(x, np.cos(x))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
plt.style.use('classic')
plt.figure(figsize=(7,7))

plt.subplot(2,2,4)
plt.plot(x, np.sin(x))

plt.subplot(2,2,2)
plt.plot(x, np.cos(x))

plt.subplot(2,2,3)
plt.plot(x, np.tan(x))


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="560">

# %%
fig, ax=plt.subplots(2,2)
ax[0,0].plot(x, np.sin(x))
ax[0,1].plot(x, np.sin(x))
ax[1,1].plot(x, np.tan(x))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## seabon

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
