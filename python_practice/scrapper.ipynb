# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\bhatt\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bhatt\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
import requests

url='https://financialservices.gov.in/new-initiatives/schemes'
response=requests.get(url)

#check if request is successful
if response.status_code==200:
    html_content=response.content

# %%
html_content
# Out:
# b'\xef\xbb\xbf<!DOCTYPE html>\r\n<!--[if IEMobile 7]><html class="iem7"  lang="en" dir="ltr"><![endif]-->\r\n<!--[if lte IE 6]><html class="lt-ie9 lt-ie8 lt-ie7"  lang="en" dir="ltr"><![endif]-->\r\n<!--[if (IE 7)&(!IEMobile)]><html class="lt-ie9 lt-ie8"  lang="en" dir="ltr"><![endif]-->\r\n<!--[if IE 8]><html class="lt-ie9"  lang="en" dir="ltr"><![endif]-->\r\n<!--[if (gte IE 9)|(gt IEMobile 7)]><!--><html  lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"><!--<![endif]-->\r\n\r\n<head>\r\n\r\n  <meta charset="utf-8" />\n<link rel="shortcut icon" href="https://financialservices.gov.in/sites/default/files/favicon.ico" type="image/vnd.microsoft.icon" />\n  \r\n  <title>Schemes | Department of Financial Services | Ministry of Finance | Government of India  \r\n  </title>\r\n \r\n    <meta name="format-detection" content="telephone=no" />\r\n    <meta name="MobileOptimized" content="width">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n    <meta name="HandheldFriendly" content="true">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\r\n\t<meta name="keywords" content="Schemes, Finance, services, revenue, ministry, department, financial, inclusion, cpc, pay commission, yojana, pension, stand up, banking, insurance, reforms, cvc, budget, CGSEL">\r\n<meta name="description" content="Financial Services covers the functioning of Banks, Financial Institutions, Insurance Companies and the National Pension System">\r\n\r\n<meta name="title" content="Department of Financial Services | Ministry of Finance | Government of India">\r\n<meta name="lang" content="en">\r\n    \r\n  <style>\n@import url("https://financialservices.gov.in/modules/system/system.base.css?rj87e6");\n</style>\n<style>\n@import url("https://financialservices.gov.in/sites/all/modules/contributed/calendar/css/calendar_multiday.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/contributed/date/date_api/date.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/contributed/date/date_popup/themes/datepicker.1.7.css?rj87e6");\n@import url("https://financialservices.gov.in/modules/field/theme/field.css?rj87e6");\n@import url("https://financialservices.gov.in/modules/node/node.css?rj87e6");\n@import url("https://financialservices.gov.in/modules/search/search.css?rj87e6");\n@import url("https://financialservices.gov.in/modules/user/user.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/contributed/views/css/views.css?rj87e6");\n</style>\n<style>\n@import url("https://financialservices.gov.in/sites/all/modules/cmf/cmf_content/assets/css/base.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/cmf/cmf_content/assets/css/font.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/cmf/cmf_content/assets/css/flexslider.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/cmf/cmf_content/assets/css/base-responsive.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/cmf/cmf_content/assets/css/font-awesome.min.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/contributed/ctools/css/ctools.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/cmf/google_search/css/result.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/modules/contributed/panels/css/panels.css?rj87e6");\n</style>\n<style>\n@import url("https://financialservices.gov.in/sites/all/themes/cmf/css/jquery.smartmarquee.css?rj87e6");\n@import url("https://financialservices.gov.in/sites/all/them ...

# %%
from bs4 import BeautifulSoup

#creating beautiful soup object
soup=BeautifulSoup(html_content, 'html.parser')

#extracting specific element
schemes=soup.find_all('h2')

# %%
schemes
# Out:
# [<h2>Pradhan Mantri Jan Dhan Yojana (PMJDY)</h2>,
#  <h2>From Jan Dhan to Jan Suraksha</h2>,
#  <h2>Pradhan Mantri Jeevan Jyoti Bima Yojana (PMJJBY)</h2>,
#  <h2>Pradhan Mantri Suraksha Bima Yojana (PMSBY)</h2>,
#  <h2>Atal Pension Yojana (APY)</h2>,
#  <h2>Pradhan Mantri Mudra Yojana</h2>,
#  <h2>Stand Up India Scheme</h2>,
#  <h2>Pradhan Mantri Vaya Vandana Yojana</h2>]

# %%
new_list=[]
for i in schemes:
    y=str(i).strip('</h2>')
    new_list.append(y)

# %%
new_list
# Out:
# ['Pradhan Mantri Jan Dhan Yojana (PMJDY)',
#  'From Jan Dhan to Jan Suraksha',
#  'Pradhan Mantri Jeevan Jyoti Bima Yojana (PMJJBY)',
#  'Pradhan Mantri Suraksha Bima Yojana (PMSBY)',
#  'Atal Pension Yojana (APY)',
#  'Pradhan Mantri Mudra Yojana',
#  'Stand Up India Scheme',
#  'Pradhan Mantri Vaya Vandana Yojana']

# %%
for i in new_list:
    y=('%',i,'%')
    new_list.append(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 for i in new_list:
#       2     y=('%',i,'%')
#       3     new_list.append(y)
#
# NameError: name 'new_list' is not defined
